# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install duckdb

# %%
# !pip install duckdb-engine
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import duckdb
from sqlalchemy import create_engine
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
conn = duckdb.connect('/content/drive/MyDrive/colab-notebooks/Projetos/oa-ac-sql-intro/data/db.duckdb')

# %%
conn.execute("CREATE TABLE minha_tabela (coluna1 INTEGER, coluna2 TEXT)")

# %%
conn.execute("INSERT INTO minha_tabela VALUES (1, 'valor1'), (2, 'valor2')")

# %%
result = conn.execute("SELECT * FROM minha_tabela")

# %%
result.fetchall()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [(1, 'valor1'), (2, 'valor2')]
